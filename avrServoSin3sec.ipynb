# %%
# Interactive Python Notebook
# Calculating a table of 8 bit signed values that will be added to a 16 bit pulse width 
# to oscillate a servo motor in a sinusoidal motion.

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# pwMax and pwMin determined by bench testing servo motor with signal generator
# desired travTime will be the approximate time the servo takes to move from full
#     left to full right.
# deltaT = 20 mS (Period for requred 50 Hz pulse to servo motor)
# steps is calculated number of steps required to cover travTime
# AVR program must load calculated pwMid to pulse width register and output to servo during setup

pwMax = 2350
pwMin = 450
pwRange = pwMax - pwMin
pwMid = int((pwMax + pwMin) / 2)
travTime = 3.0
deltaT = .02
steps = int(travTime / deltaT)

print("  Max:", pwMax, "  Min:", pwMin, "  Mid:", pwMid, "  Range:", pwRange, "  Steps:", steps)

# Generate list of sin() values with peaks at pwMax and pwMin
data = []
for t in range(steps):
    pos = int(pwRange / 2 * np.sin(t * 2 * np.pi / steps) + pwMid)
    data.append(pos)

print("\nPulse Widths:\n", data)
plt.plot(data)
plt.show()
print("\nCalculated Min:", min(data), "  Calculated Max:", max(data))

# Generate list of step sizes that can be added to Pulse Width register
stepSize = []
stepSizeSigned = []
for i, d in enumerate(data):
    size = data[(i + 1)%len(data)] - d
    stepSize.append(size)
    stepSizeSigned.append(size if size >= 0 else 256 + size)

print("\nStep Size\n", stepSize)

plt.plot(stepSize)
plt.show()

print("\nStep Size 8 bit Signed\n", stepSizeSigned)
print("\n\nExample adding 8 bit signed step size to 16 bit Pulse Width Register high and low bytes named pwH:pwL")
print("using TempH and TempL to hold step size value\n")

# Printing Assembly Language Function to read next value in Flash Memory
print("\
\n\tld  \tTempL, X+\t;X = SRAM address of signed step size value\
\n\tclr \tTempH\
\n\tsbrc\tTempL, 7\t;Check sign bit and set high byte to 0xFF if it is set\
\n\tser \tTempH\
\n\tadd \tpwL, TempL\n\tadc\tpwH, TempH\
\n")

# Generating a string containing all 8 bit signed hex values formatted as a table with .db (define byte)
# directives that can be included in the AVR program.

TaddLable = "TABLEaddr" + str(travTime).replace(".","_")
TendLable = "TABLEend" + str(travTime).replace(".","_")

Table = TaddLable + ":\n.db\t"
for i, s in enumerate(stepSizeSigned):
    Table += "$" + hex(s)[2:].zfill(2).upper()
    Table += "\n.db\t" if i % 8 == 7 and i < len(stepSizeSigned) - 1 else\
    "\n" if i >= len(stepSizeSigned) - 1 else ",\t"
Table += TendLable + ":"

print("\nOption using data table stored in FLASH Memory\
\n; Typically SRAM space is limited so it may be advantageous to keep\
\n; data tables in FLASH memory.  Special consideration must be taken\
\n; when addressing word addressed Flash memory\
\n; Z Register is used for the LPM instruction.  (Load Program Memory)\
\n; Set Z address to beginning of data table.\
\n; Program Memory uses WORD addressing.  2 Bytes for each address.\
\n; LPM uses BYTE addressing.  1 Byte for each address.\
\n; Multiply WORD address by 2 to calculate BYTE address.\
\n; Shifting a Byte Left once is the the same as multiplying it by 2.\
\n; (Value << 1) = (Value * 2)\n\
\n " + Table + "\n\
\n;directives requred before setup:\
\n.equ\tpwMid = ", pwMid, "\
\n.def\tTempH = R17\
\n.def\tTempL = R16\
\n.def\tpwH = R19\
\n.def\tpwL = R18\
\n\n;Instructions required during setup\
\n\tldi \tpwH, high(pwMid)\t;pwMid value = ", pwMid, "\
\n\tldi \tpwL, low(pwMid)\
\n\tldi \tZH, high(" + TaddLable + " << 1)\
\n\tldi \tZL, low(" + TaddLable + " << 1)\
\n")

# Printing Assembly Language Function to read next value in StepSize table
print("\
\n;Load and Store ZH:ZL as needed (It may be used by other code)\
\n;Function to read next value from table in Flash Memory  \
\nreadNextStep:\
\n\tlpm \tTempL, Z+\t;Z = FLASH Memory address of signed step size value\
\n\tclr \tTempH\
\n\tsbrc\tTempL, 7\t;Check sign bit and set high byte to 0xFF if it is set\
\n\tser \tTempH\
\n\tadd \tpwL, TempL\
\n\tadc \tpwH, TempH\
\n\tldi \tTempH, high(" + TendLable + " << 1)\
\n\tldi \tTempL, low(" + TendLable + " << 1)\
\n\tcp  \tZL, TempL\
\n\tcpc \tZH, TempH\
\n\tbrne\tnot" + "TABLEend" + str(travTime).replace('.', '_') + "\
\n\tldi \tZH, high(" + TaddLable + " << 1)\
\n\tldi \tZL, low(" + TaddLable + " << 1)\
\nnotTableEnd" + str(travTime).replace('.','_') + ":\
\n\tret\
")
# Out:
#   Max: 2350   Min: 450   Mid: 1400   Range: 1900   Steps: 150
#
# Pulse Widths:
#  [1400, 1439, 1479, 1519, 1558, 1597, 1636, 1674, 1712, 1749, 1786, 1822, 1857, 1892, 1925, 1958, 1990, 2020, 2050, 2078, 2105, 2131, 2156, 2180, 2202, 2222, 2241, 2259, 2275, 2290, 2303, 2315, 2324, 2333, 2339, 2344, 2348, 2349, 2349, 2348, 2344, 2339, 2333, 2324, 2315, 2303, 2290, 2275, 2259, 2241, 2222, 2202, 2180, 2156, 2131, 2105, 2078, 2050, 2020, 1990, 1958, 1925, 1892, 1857, 1822, 1786, 1749, 1712, 1674, 1636, 1597, 1558, 1519, 1479, 1439, 1400, 1360, 1320, 1280, 1241, 1202, 1163, 1125, 1087, 1050, 1013, 977, 942, 907, 874, 841, 809, 779, 749, 721, 694, 668, 643, 619, 597, 577, 558, 540, 524, 509, 496, 484, 475, 466, 460, 455, 451, 450, 450, 451, 455, 460, 466, 475, 484, 496, 509, 524, 540, 558, 577, 597, 619, 643, 668, 694, 721, 749, 779, 809, 841, 874, 907, 942, 977, 1013, 1050, 1087, 1125, 1163, 1202, 1241, 1280, 1320, 1360]
# Calculated Min: 450   Calculated Max: 2349
#
# Step Size
#  [39, 40, 40, 39, 39, 39, 38, 38, 37, 37, 36, 35, 35, 33, 33, 32, 30, 30, 28, 27, 26, 25, 24, 22, 20, 19, 18, 16, 15, 13, 12, 9, 9, 6, 5, 4, 1, 0, -1, -4, -5, -6, -9, -9, -12, -13, -15, -16, -18, -19, -20, -22, -24, -25, -26, -27, -28, -30, -30, -32, -33, -33, -35, -35, -36, -37, -37, -38, -38, -39, -39, -39, -40, -40, -39, -40, -40, -40, -39, -39, -39, -38, -38, -37, -37, -36, -35, -35, -33, -33, -32, -30, -30, -28, -27, -26, -25, -24, -22, -20, -19, -18, -16, -15, -13, -12, -9, -9, -6, -5, -4, -1, 0, 1, 4, 5, 6, 9, 9, 12, 13, 15, 16, 18, 19, 20, 22, 24, 25, 26, 27, 28, 30, 30, 32, 33, 33, 35, 35, 36, 37, 37, 38, 38, 39, 39, 39, 40, 40, 40]
# Step Size 8 bit Signed
#  [39, 40, 40, 39, 39, 39, 38, 38, 37, 37, 36, 35, 35, 33, 33, 32, 30, 30, 28, 27, 26, 25, 24, 22, 20, 19, 18, 16, 15, 13, 12, 9, 9, 6, 5, 4, 1, 0, 255, 252, 251, 250, 247, 247, 244, 243, 241, 240, 238, 237, 236, 234, 232, 231, 230, 229, 228, 226, 226, 224, 223, 223, 221, 221, 220, 219, 219, 218, 218, 217, 217, 217, 216, 216, 217, 216, 216, 216, 217, 217, 217, 218, 218, 219, 219, 220, 221, 221, 223, 223, 224, 226, 226, 228, 229, 230, 231, 232, 234, 236, 237, 238, 240, 241, 243, 244, 247, 247, 250, 251, 252, 255, 0, 1, 4, 5, 6, 9, 9, 12, 13, 15, 16, 18, 19, 20, 22, 24, 25, 26, 27, 28, 30, 30, 32, 33, 33, 35, 35, 36, 37, 37, 38, 38, 39, 39, 39, 40, 40, 40]
#
#
# Example adding 8 bit signed step size to 16 bit Pulse Width Register high and low bytes named pwH:pwL
# using TempH and TempL to hold step size value
#
#
# 	ld  	TempL, X+	;X = SRAM address of signed step size value
# 	clr 	TempH
# 	sbrc	TempL, 7	;Check sign bit and set high byte to 0xFF if it is set
# 	ser 	TempH
# 	add 	pwL, TempL
# 	adc	pwH, TempH
#
#
# Option using data table stored in FLASH Memory
# ; Typically SRAM space is limited so it may be advantageous to keep
# ; data tables in FLASH memory.  Special consideration must be taken
# ; when addressing word addressed Flash memory
# ; Z Register is used for the LPM instruction.  (Load Program Memory)
# ; Set Z address to beginning of data table.
# ; Program Memory uses WORD addressing.  2 Bytes for each address.
# ; LPM uses BYTE addressing.  1 Byte for each address.
# ; Multiply WORD address by 2 to calculate BYTE address.
# ; Shifting a Byte Left once is the the same as multiplying it by 2.
# ; (Value << 1) = (Value * 2)
#
#  TABLEaddr3_0:
# .db	$27,	$28,	$28,	$27,	$27,	$27,	$26,	$26
# .db	$25,	$25,	$24,	$23,	$23,	$21,	$21,	$20
# .db	$1E,	$1E,	$1C,	$1B,	$1A,	$19,	$18,	$16
# .db	$14,	$13,	$12,	$10,	$0F,	$0D,	$0C,	$09
# .db	$09,	$06,	$05,	$04,	$01,	$00,	$FF,	$FC
# .db	$FB,	$FA,	$F7,	$F7,	$F4,	$F3,	$F1,	$F0
# .db	$EE,	$ED,	$EC,	$EA,	$E8,	$E7,	$E6,	$E5
# .db	$E4,	$E2,	$E2,	$E0,	$DF,	$DF,	$DD,	$DD
# .db	$DC,	$DB,	$DB,	$DA,	$DA,	$D9,	$D9,	$D9
# .db	$D8,	$D8,	$D9,	$D8,	$D8,	$D8,	$D9,	$D9
# .db	$D9,	$DA,	$DA,	$DB,	$DB,	$DC,	$DD,	$DD
# .db	$DF,	$DF,	$E0,	$E2,	$E2,	$E4,	$E5,	$E6
# .db	$E7,	$E8,	$EA,	$EC,	$ED,	$EE,	$F0,	$F1
# .db	$F3,	$F4,	$F7,	$F7,	$FA,	$FB,	$FC,	$FF
# .db	$00,	$01,	$04,	$05,	$06,	$09,	$09,	$0C
# .db	$0D,	$0F,	$10,	$12,	$13,	$14,	$16,	$18
# .db	$19,	$1A,	$1B,	$1C,	$1E,	$1E,	$20,	$21
# .db	$21,	$23,	$23,	$24,	$25,	$25,	$26,	$26
# .db	$27,	$27,	$27,	$28,	$28,	$28
# TABLEend3_0:
#
# ;directives requred before setup:
# .equ	pwMid =  1400
# .def	TempH = R17
# .def	TempL = R16
# .def	pwH = R19
# .def	pwL = R18
#
# ;Instructions required during setup
# 	ldi 	pwH, high(pwMid)	;pwMid value =  1400
# 	ldi 	pwL, low(pwMid)
# 	ldi 	ZH, high(TABLEaddr3_0 << 1)
# 	ldi 	ZL, low(TABLEaddr3_0 << 1)
#
#
# ;Load and Store ZH:ZL as needed (It may be used by other code)
# ;Function to read next value from table in Flash Memory
# readNextStep:
# 	lpm 	TempL, Z+	;Z = FLASH Memory address of signed step size value
# 	clr 	TempH
# 	sbrc	TempL, 7	;Check sign bit and set high byte to 0xFF if it is set
# 	ser 	TempH
# 	add 	pwL, TempL
# 	adc 	pwH, TempH
# 	ldi 	TempH, high(TABLEend3_0 << 1)
# 	ldi 	TempL, low(TABLEend3_0 << 1)
# 	cp  	ZL, TempL
# 	cpc 	ZH, TempH
# 	brne	notTABLEend3_0
# 	ldi 	ZH, high(TABLEaddr3_0 << 1)
# 	ldi 	ZL, low(TABLEaddr3_0 << 1)
# notTableEnd3_0:
# 	ret

# %% [markdown]
# <b>Additional Documents with different travel times:</b><br><br>
# [1 Second Period](avrServoSin1sec.html)<br><br>
# [1.5 Second Period](avrServoSin1_5sec.html)<br><br>
# [2 Second Period](avrServoSin2sec.html)<br><br>
# [4 Second Period](avrServoSin4sec.html)
